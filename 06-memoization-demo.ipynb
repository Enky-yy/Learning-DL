# %%
import time
def fib(n):
    if n==1 or n==0:
        return 1
    else:
        return fib(n-1) + fib(n-2)

# %%
fib(40)
# Out:
# 165580141

# %%
start = time.time()
fib(40)
print(time.time()-start)
# Out:
# 9.792415857315063
