# %%
import numpy as np
from distributed.utils_test import padded_time

faqs = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies
You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390
Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at nitish.campusx@gmail.com
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmail.com
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmai.com
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS']='0'
import tensorflow
from keras.layers import TextVectorization
# Out:
# 2026-03-04 21:11:50.684660: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
vectorization = TextVectorization()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772638912.241683  476469 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4174 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
vectorization.adapt(faqs.split('\n'))

# %%
vocab_size=len(vectorization.get_vocabulary())

# %%
input_seq=[]

for sentence in faqs.split('\n'):
    content = vectorization(sentence)

    for i in range (1,len(content)):
        n_gram = content[:i+1]
        input_seq.append(n_gram)

# %%
 input_seq23 = vectorization(faqs.split('\n'))

# %%
input_seq23
# Out:
# <tf.Tensor: shape=(78, 57), dtype=int64, numpy=
# array([[137,   2,  14, ...,   0,   0,   0],
#        [ 12,   8,   2, ...,   0,   0,   0],
#        [  2,  13, 122, ...,   0,   0,   0],
#        ...,
#        [ 16,  87, 213, ...,   0,   0,   0],
#        [234,  17, 208, ...,   0,   0,   0],
#        [  0,   0,   0, ...,   0,   0,   0]], shape=(78, 57))>

# %%
input_seq
# Out:
# [<tf.Tensor: shape=(2,), dtype=int64, numpy=array([137,   2])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([137,   2,  14])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12,  8])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12,  8,  2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([12,  8,  2, 13])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([12,  8,  2, 13, 48])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([12,  8,  2, 13, 48, 15])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([12,  8,  2, 13, 48, 15, 57])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([12,  8,  2, 13, 48, 15, 57, 68])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 12,   8,   2,  13,  48,  15,  57,  68, 113])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 12,   8,   2,  13,  48,  15,  57,  68, 113,  14])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 12,   8,   2,  13,  48,  15,  57,  68, 113,  14, 230])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 12,   8,   2,  13,  48,  15,  57,  68, 113,  14, 230, 274])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 2, 13])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([  2,  13, 122])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([  2,  13, 122,   7])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([  2,  13, 122,   7,  45])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33, 109])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33, 109,  31])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33, 109,  31,   3])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9,   5])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9,   5,  28])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9,   5,  28,  45])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9,   5,  28,  45,
#          70])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9,   5,  28,  45,
#          70,   6])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9,   5,  28,  45,
#          70,   6,  36])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  2,  13, 122,   7,  45,  33, 109,  31,   3,   9,   5,  28,  45,
#          70,   6,  36, 266])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12,  8])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12,  8,  2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([12,  8,  2, 63])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([12,  8,  2, 63, 79])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([12,  8,  2, 63, 79,  6])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([12,  8,  2, 63, 79,  6,  2])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([12,  8,  2, 63, 79,  6,  2, 13])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 2, 63])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 2, 63, 79])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 2, 63, 79,  6])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8, 84])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8, 84, 73])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8, 84, 73, 34])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8, 84, 73, 34,  2])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8, 84, 73, 34,  2, 63])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8, 84, 73, 34,  2, 63, 13])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=array([ 2, 63, 79,  6,  2, 13,  8, 84, 73, 34,  2, 63, 13, 48])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  2,  63,  79,   6,   2,  13,   8,  84,  73,  34,   2,  63,  13,
#          48, 252])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  2,  63,  79,   6,   2,  13,   8,  84,  73,  34,   2,  63,  13,
#          48, 252, 267])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  2,  63,  79,   6,   2,  13,   8,  84,  73,  34,   2,  63,  13,
#          48, 252, 267,  36])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([  2,  63,  79,   6,   2,  13,   8,  84,  73,  34,   2,  63,  13,
#          48, 252, 267,  36, 270])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12,  8])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12,  8,  2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([12,  8,  2, 92])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([12,  8,  2, 92,  6])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([12,  8,  2, 92,  6,  2])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 12,   8,   2,  92,   6,   2, 113])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 12,   8,   2,  92,   6,   2, 113,  14])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([25, 10])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([25, 10, 22])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 25,  10,  22, 241])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 25,  10,  22, 241,   2])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 25,  10,  22, 241,   2, 222])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 25,  10,  22, 241,   2, 222, 189])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([103, 221])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([103, 201])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([103, 201,  15])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([103, 201,  15,  57])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([103, 201,  15,  57,  68])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 57, 262])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([158,  15])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([158,  15,  57])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([158,  15,  57,  68])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([194,  15])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([194,  15, 197])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([194,  15, 197,  74])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([110, 264])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([177, 110])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([82, 95])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 3, 11])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([  3,  11, 245])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([  3,  11, 245,   2])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([  3,  11, 245,   2, 236])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  3,  11, 245,   2, 236,  92])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([  3,  11, 245,   2, 236,  92,  77])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  3,  11, 245,   2, 236,  92,  77, 215])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 10, 126])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 10, 126,  74])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 10, 126,  74,  23])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 10, 126,  74,  23, 107])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 10, 126,  74,  23, 107,  22])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 10, 126,  74,  23, 107,  22,   7])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 10, 126,  74,  23, 107,  22,   7,  71])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 10, 126,  74,  23, 107,  22,   7,  71,   6])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 10, 126,  74,  23, 107,  22,   7,  71,   6,  20])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 10, 126,  74,  23, 107,  22,   7,  71,   6,  20,  14])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([106, 107])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([106, 107,  23])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([106, 107,  23, 126])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([106, 107,  23, 126,  74])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250,  61])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250,  61,  44])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250,  61,  44,   7])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250,  61,  44,   7,  71])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250,  61,  44,   7,  71,   6])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250,  61,  44,   7,  71,   6,  20])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([106, 107,  23, 126,  74, 250,  61,  44,   7,  71,   6,  20, 176])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([106, 107,  23, 126,  74, 250,  61,  44,   7,  71,   6,  20, 176,
#         237])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12, 21])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12, 21,  4])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 12,  21,   4, 111])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115,  35])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115,  35,  10])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115,  35,  10,   4])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115,  35,  10,   4,  47])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115,  35,  10,   4,  47,   7])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115,  35,  10,   4,  47,   7, 100])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 12,  21,   4, 111,   7, 115,  35,  10,   4,  47,   7, 100,   6])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([ 12,  21,   4, 111,   7, 115,  35,  10,   4,  47,   7, 100,   6,
#           2])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([ 12,  21,   4, 111,   7, 115,  35,  10,   4,  47,   7, 100,   6,
#           2,  35])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([41, 19])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([41, 19, 39])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([41, 19, 39, 16])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([41, 19, 39, 16, 61])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170,  34])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170,  34, 123])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170,  34, 123,  21])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3,  11])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3,  11, 220])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3,  11, 220, 256])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3,  11, 220, 256,  23])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3,  11, 220, 256,  23,  51])>,
#  <tf.Tensor: shape=(20,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3,  11, 220, 256,  23,  51,   2])>,
#  <tf.Tensor: shape=(21,), dtype=int64, numpy=
#  array([ 41,  19,  39,  16,  61, 170,  34, 123,  21,   3, 111,   7,  35,
#           3,  11, 220, 256,  23,  51,   2, 100])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([31, 11])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([31, 11,  4])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 31,  11,   4, 223])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 31,  11,   4, 223,   2])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 31,  11,   4, 223,   2, 131])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 31,  11,   4, 223,   2, 131, 167])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([244,  20])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([244,  20,  78])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([244,  20,  78, 164])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([244,  20,  78, 164,   5])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67,  53])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67,  53,  59])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67,  53,  59,  53])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67,  53,  59,  53,  91])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67,  53,  59,  53,  91, 155])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67,  53,  59,  53,  91, 155,   6])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([244,  20,  78, 164,   5,  67,  53,  59,  53,  91, 155,   6,   2])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([244,  20,  78, 164,   5,  67,  53,  59,  53,  91, 155,   6,   2,
#          13])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([244,  20,  78, 164,   5,  67,  53,  59,  53,  91, 155,   6,   2,
#          13, 217])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12,  8])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12,  8,  2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([12,  8,  2, 91])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([12,  8,  2, 91, 79])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([12,  8,  2, 91, 79,  6])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([12,  8,  2, 91, 79,  6, 19])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([12,  8,  2, 91, 79,  6, 19,  2])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 12,   8,   2,  91,  79,   6,  19,   2, 115])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 12,   8,   2,  91,  79,   6,  19,   2, 115,  16])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([168,  19])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([168,  19,   2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([168,  19,   2,  16])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([168,  19,   2,  16, 203])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([168,  19,   2,  16, 203, 139])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([168,  19,   2,  16, 203, 139, 218])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12,  8])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12,  8,  2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 12,   8,   2, 204])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 12,   8,   2, 204, 159])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 12,   8,   2, 204, 159,  59])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 12,   8,   2, 204, 159,  59,   2])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 12,   8,   2, 204, 159,  59,   2, 210])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 12,   8,   2, 204, 159,  59,   2, 210, 229])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 12,   8,   2, 204, 159,  59,   2, 210, 229,   2])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 12,   8,   2, 204, 159,  59,   2, 210, 229,   2,  16])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([119,  10])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([119,  10,   4])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([119,  10,   4,  22])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([119,  10,   4,  22, 212])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([119,  10,   4,  22, 212, 137])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([119,  10,   4,  22, 212, 137,   2])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([119,  10,   4,  22, 212, 137,   2, 149])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([119,  10,   4,  22, 212, 137,   2, 149, 131])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 3, 10])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 3, 10, 47])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 3, 10, 47,  7])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 3, 10, 47,  7, 54])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 3, 10, 47,  7, 54, 55])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 3, 10, 47,  7, 54, 55, 39])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  3,  10,  47,   7,  54,  55,  39, 163])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([  3,  10,  47,   7,  54,  55,  39, 163, 251])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,  35])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,  35,  43])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,  35,  43,
#           3])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,  35,  43,
#           3, 253])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,  35,  43,
#           3, 253,   7])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,  35,  43,
#           3, 253,   7,  38])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([  3,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,  35,  43,
#           3, 253,   7,  38, 148])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([11,  4])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([11,  4, 29])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([11,  4, 29, 20])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([11,  4, 29, 20, 13])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([11,  4, 29, 20, 13, 21])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([11,  4, 29, 20, 13, 21,  4])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([11,  4, 29, 20, 13, 21,  4, 24])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([11,  4, 29, 20, 13, 21,  4, 24, 55])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([11,  4, 29, 20, 13, 21,  4, 24, 55,  7])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 11,   4,  29,  20,  13,  21,   4,  24,  55,   7, 187])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 11,   4,  29,  20,  13,  21,   4,  24,  55,   7, 187, 255])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 41, 136])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 4, 24])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 4, 24, 75])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 4, 24, 75, 11])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 4, 24, 75, 11,  4])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 4, 24, 75, 11,  4, 46])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 4, 24, 75, 11,  4, 46,  2])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 4, 24, 75, 11,  4, 46,  2, 14])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 4, 24, 75, 11,  4, 46,  2, 14, 18])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 4, 24, 75, 11,  4, 46,  2, 14, 18,  2])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  4,  24,  75,  11,   4,  46,   2,  14,  18,   2, 112])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([136,   3])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([136,   3,  11])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([136,   3,  11,  46])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([136,   3,  11,  46,   2])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([136,   3,  11,  46,   2,  14])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([136,   3,  11,  46,   2,  14, 134])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([21,  4])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 21,   4, 205])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 21,   4, 205,  18])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112,  10])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112,  10,   4])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112,  10,   4,  22])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112,  10,   4,  22,  40])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112,  10,   4,  22,  40,   5])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112,  10,   4,  22,  40,   5,  67])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 21,   4, 205,  18,   2, 112,  10,   4,  22,  40,   5,  67,  19])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([ 21,   4, 205,  18,   2, 112,  10,   4,  22,  40,   5,  67,  19,
#           2])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([ 21,   4, 205,  18,   2, 112,  10,   4,  22,  40,   5,  67,  19,
#           2,  42])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([ 21,   4, 205,  18,   2, 112,  10,   4,  22,  40,   5,  67,  19,
#           2,  42, 202])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([41, 43])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([41, 43,  3])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([41, 43,  3, 28])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([41, 43,  3, 28,  2])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10, 22])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10, 22, 40])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10, 22, 40,  5])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10, 22, 40,  5, 67])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10, 22, 40,  5, 67, 19])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10, 22, 40,  5, 67, 19,  2])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=array([41, 43,  3, 28,  2, 26,  3, 10, 22, 40,  5, 67, 19,  2, 42])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([ 41,  43,   3,  28,   2,  26,   3,  10,  22,  40,   5,  67,  19,
#           2,  42, 242])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([ 41,  43,   3,  28,   2,  26,   3,  10,  22,  40,   5,  67,  19,
#           2,  42, 242,  18])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([ 41,  43,   3,  28,   2,  26,   3,  10,  22,  40,   5,  67,  19,
#           2,  42, 242,  18,  30])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([ 41,  43,   3,  28,   2,  26,   3,  10,  22,  40,   5,  67,  19,
#           2,  42, 242,  18,  30,  81])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([31, 29])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([31, 29,  4])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([31, 29,  4,  9])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([31, 29,  4,  9,  5])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([31, 29,  4,  9,  5, 94])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([31, 29,  4,  9,  5, 94,  2])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([31, 29,  4,  9,  5, 94,  2, 66])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 3, 80])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 3, 80,  9])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 3, 80,  9,  5])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 3, 80,  9,  5, 94])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 3, 80,  9,  5, 94,  2])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 3, 80,  9,  5, 94,  2, 66])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 3, 80,  9,  5, 94,  2, 66, 25])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 3, 80,  9,  5, 94,  2, 66, 25, 10])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3,   9])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3,   9,   5])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3,   9,   5, 165])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3,   9,   5, 165, 226])>,
#  <tf.Tensor: shape=(20,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3,   9,   5, 165, 226,   2])>,
#  <tf.Tensor: shape=(21,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3,   9,   5, 165, 226,   2,  66])>,
#  <tf.Tensor: shape=(22,), dtype=int64, numpy=
#  array([  3,  80,   9,   5,  94,   2,  66,  25,  10, 175,   3,  87,   2,
#         160,   3,   9,   5, 165, 226,   2,  66, 142])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([10, 25])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([10, 25, 29])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([10, 25, 29, 82])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([10, 25, 29, 82, 95])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([10, 25, 29, 82, 95, 18])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([10, 25, 29, 82, 95, 18,  2])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([10, 25, 29, 82, 95, 18,  2, 14])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([31, 11])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([31, 11, 25])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([31, 11, 25, 58])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([31, 11, 25, 58,  3])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 3, 11])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 3, 11, 54])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 3, 11, 54, 52])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 3, 11, 54, 52, 60])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  3,  11,  54,  52,  60, 108])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([183,  98])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([183,  98, 172])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([31, 29])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([31, 29, 25])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([31, 29, 25,  9])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([31, 29, 25,  9,  5])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([31, 29, 25,  9,  5, 28])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([31, 29, 25,  9,  5, 28, 39])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([31, 29, 25,  9,  5, 28, 39, 70])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([31, 29, 25,  9,  5, 28, 39, 70, 30])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 31,  29,  25,   9,   5,  28,  39,  70,  30, 141])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 31,  29,  25,   9,   5,  28,  39,  70,  30, 141, 246])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 31,  29,  25,   9,   5,  28,  39,  70,  30, 141, 246,  72])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 31,  29,  25,   9,   5,  28,  39,  70,  30, 141, 246,  72,  32])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([3, 9])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([3, 9, 5])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 3,  9,  5, 28])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45, 70])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45, 70, 17])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45, 70, 17, 39])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45, 70, 17, 39, 32])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45, 70, 17, 39, 32, 77])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45, 70, 17, 39, 32, 77,  8])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=array([ 3,  9,  5, 28, 19, 30, 45, 70, 17, 39, 32, 77,  8,  2])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  3,   9,   5,  28,  19,  30,  45,  70,  17,  39,  32,  77,   8,
#           2, 116])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  3,   9,   5,  28,  19,  30,  45,  70,  17,  39,  32,  77,   8,
#           2, 116,  15])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  3,   9,   5,  28,  19,  30,  45,  70,  17,  39,  32,  77,   8,
#           2, 116,  15,  39])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([  3,   9,   5,  28,  19,  30,  45,  70,  17,  39,  32,  77,   8,
#           2, 116,  15,  39,  32])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([  3,   9,   5,  28,  19,  30,  45,  70,  17,  39,  32,  77,   8,
#           2, 116,  15,  39,  32, 216])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([11, 25])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([11, 25, 27])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([11, 25, 27,  2])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124, 263])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124, 263,   6])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124, 263,   6,  36])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124, 263,   6,  36, 138])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124, 263,   6,  36, 138,  19])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124, 263,   6,  36, 138,  19,  60])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 11,  25,  27,   2, 124, 263,   6,  36, 138,  19,  60,  43])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([150, 106])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([150, 106,   2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([150, 106,   2,  14])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([150, 106,   2,  14, 122])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([150, 106,   2,  14, 122,   7])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([150, 106,   2,  14, 122,   7,  45])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([150, 106,   2,  14, 122,   7,  45,  33])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([150, 106,   2,  14, 122,   7,  45,  33, 109])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12,  8])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12,  8,  2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([12,  8,  2, 62])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([12,  8,  2, 62,  6])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33, 93])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33, 93, 21])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33, 93, 21,  4])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33, 93, 21,  4, 27])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33, 93, 21,  4, 27, 17])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33, 93, 21,  4, 27, 17, 86])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=array([12,  8,  2, 62,  6, 45, 33, 93, 21,  4, 27, 17, 86, 76])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5])>,
#  <tf.Tensor: shape=(20,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27])>,
#  <tf.Tensor: shape=(21,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27, 135])>,
#  <tf.Tensor: shape=(22,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27, 135,  17])>,
#  <tf.Tensor: shape=(23,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27, 135,  17, 275])>,
#  <tf.Tensor: shape=(24,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27, 135,  17, 275,  49])>,
#  <tf.Tensor: shape=(25,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27, 135,  17, 275,  49,  72])>,
#  <tf.Tensor: shape=(26,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27, 135,  17, 275,  49,  72,  86])>,
#  <tf.Tensor: shape=(27,), dtype=int64, numpy=
#  array([ 12,   8,   2,  62,   6,  45,  33,  93,  21,   4,  27,  17,  86,
#          76, 153,  29,   4,   9,   5,  27, 135,  17, 275,  49,  72,  86,
#          49])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([86, 49])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([86, 49,  2])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([86, 49,  2, 62])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([86, 49,  2, 62, 69])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([86, 49,  2, 62, 69,  8])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 86,  49,   2,  62,  69,   8, 271])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 86,  49,   2,  62,  69,   8, 271, 127])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 86,  49,   2,  62,  69,   8, 271, 127,  55])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11])>,
#  <tf.Tensor: shape=(20,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46])>,
#  <tf.Tensor: shape=(21,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134])>,
#  <tf.Tensor: shape=(22,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3])>,
#  <tf.Tensor: shape=(23,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80])>,
#  <tf.Tensor: shape=(24,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9])>,
#  <tf.Tensor: shape=(25,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9,   5])>,
#  <tf.Tensor: shape=(26,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9,   5, 145])>,
#  <tf.Tensor: shape=(27,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9,   5, 145,
#          15])>,
#  <tf.Tensor: shape=(28,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9,   5, 145,
#          15,   7])>,
#  <tf.Tensor: shape=(29,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9,   5, 145,
#          15,   7,  53])>,
#  <tf.Tensor: shape=(30,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9,   5, 145,
#          15,   7,  53,   5])>,
#  <tf.Tensor: shape=(31,), dtype=int64, numpy=
#  array([ 86,  49,   2,  62,  69,   8, 271, 127,  55,   2, 128,   3,  28,
#           2,  26,  34, 227,   3,  11,  46, 134,   3,  80,   9,   5, 145,
#          15,   7,  53,   5, 228])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([12, 21])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([12, 21,  4])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([12, 21,  4, 80])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2,  13])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2,  13,  83])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2,  13,  83, 195])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2,  13,  83, 195,   2])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2,  13,  83, 195,   2,  26])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2,  13,  83, 195,   2,  26,  12])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 12,  21,   4,  80, 199,   2,  13,  83, 195,   2,  26,  12,   8])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([ 12,  21,   4,  80, 199,   2,  13,  83, 195,   2,  26,  12,   8,
#           2])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([ 12,  21,   4,  80, 199,   2,  13,  83, 195,   2,  26,  12,   8,
#           2,  99])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([ 12,  21,   4,  80, 199,   2,  13,  83, 195,   2,  26,  12,   8,
#           2,  99, 180])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 3, 47])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 3, 47,  7])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 3, 47,  7, 84])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([  3,  47,   7,  84, 127])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99,  69])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99,  69,  55])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99,  69,  55,   2])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99,  69,  55,   2, 128])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99,  69,  55,   2, 128,   3])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99,  69,  55,   2, 128,   3,   9])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  3,  47,   7,  84, 127,  99,  69,  55,   2, 128,   3,   9, 196])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([  3,  47,   7,  84, 127,  99,  69,  55,   2, 128,   3,   9, 196,
#           2])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  3,  47,   7,  84, 127,  99,  69,  55,   2, 128,   3,   9, 196,
#           2,  26])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 4, 24])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([  4,  24, 114])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([  4,  24, 114, 105])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([  4,  24, 114, 105, 118])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23,   4])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23,   4,  24])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23,   4,  24,  44])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26,  17])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26,  17,   2])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26,  17,   2,  32])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26,  17,   2,  32,  12])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26,  17,   2,  32,  12,  96])>,
#  <tf.Tensor: shape=(20,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26,  17,   2,  32,  12,  96,   4])>,
#  <tf.Tensor: shape=(21,), dtype=int64, numpy=
#  array([  4,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#          26,  17,   2,  32,  12,  96,   4,  29])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([3, 9])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([3, 9, 5])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 3,  9,  5, 58])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 3,  9,  5, 58, 52])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 3,  9,  5, 58, 52, 59])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 3,  9,  5, 58, 52, 59, 97])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 3,  9,  5, 58, 52, 59, 97,  7])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 3,  9,  5, 58, 52, 59, 97,  7, 54])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 3,  9,  5, 58, 52, 59, 97,  7, 54, 60])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  3,   9,   5,  58,  52,  59,  97,   7,  54,  60, 108])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([178, 169])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([178, 169, 102])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 64, 144])>,
# ...
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11,   4])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11,   4,  27])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11,   4,  27,  26])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11,   4,  27,  26,   6])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11,   4,  27,  26,   6,   2])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11,   4,  27,  26,   6,   2, 125])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  4,  24, 206,  75, 119,  11,   4,  27,  26,   6,   2, 125,  73])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([ 3, 10])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 3, 10, 47])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 3, 10, 47,  7])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([  3,  10,  47,   7, 116])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5,  27])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5,  27,  48])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5,  27,  48,   6])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81,  43])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81,  43,   3])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81,  43,   3,  27])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81,  43,   3,  27,  15])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81,  43,   3,  27,  15,   2])>,
#  <tf.Tensor: shape=(20,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81,  43,   3,  27,  15,   2, 238])>,
#  <tf.Tensor: shape=(21,), dtype=int64, numpy=
#  array([  3,  10,  47,   7, 116,   5,  27,  48,   6, 125,  73,  18,  30,
#          81,  43,   3,  27,  15,   2, 238,  53])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([4, 9])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([  4,   9, 101])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([  4,   9, 101,  65])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([  4,   9, 101,  65,  37])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50,   8])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50,   8,   7])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50,   8,   7,  71])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6,  20])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6,  20,  14])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6,  20,  14,  12])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6,  20,  14,  12,
#         129])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6,  20,  14,  12,
#         129,  90])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6,  20,  14,  12,
#         129,  90,  37])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([  4,   9, 101,  65,  37,  50,   8,   7,  71,   6,  20,  14,  12,
#         129,  90,  37,  50])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([20,  8])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([20,  8,  5])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 20,   8,   5, 243])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65])>,
#  <tf.Tensor: shape=(6,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37,  50])>,
#  <tf.Tensor: shape=(8,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37,  50, 233])>,
#  <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37,  50, 233,  44])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192])>,
#  <tf.Tensor: shape=(11,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37])>,
#  <tf.Tensor: shape=(12,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120])>,
#  <tf.Tensor: shape=(13,), dtype=int64, numpy=array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34])>,
#  <tf.Tensor: shape=(14,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25])>,
#  <tf.Tensor: shape=(15,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232])>,
#  <tf.Tensor: shape=(16,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120])>,
#  <tf.Tensor: shape=(17,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3])>,
#  <tf.Tensor: shape=(18,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261])>,
#  <tf.Tensor: shape=(19,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207])>,
#  <tf.Tensor: shape=(20,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72])>,
#  <tf.Tensor: shape=(21,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15])>,
#  <tf.Tensor: shape=(22,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65])>,
#  <tf.Tensor: shape=(23,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193])>,
#  <tf.Tensor: shape=(24,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123])>,
#  <tf.Tensor: shape=(25,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209])>,
#  <tf.Tensor: shape=(26,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248])>,
#  <tf.Tensor: shape=(27,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34])>,
#  <tf.Tensor: shape=(28,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21])>,
#  <tf.Tensor: shape=(29,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3])>,
#  <tf.Tensor: shape=(30,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61])>,
#  <tf.Tensor: shape=(31,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181])>,
#  <tf.Tensor: shape=(32,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5])>,
#  <tf.Tensor: shape=(33,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46])>,
#  <tf.Tensor: shape=(34,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20])>,
#  <tf.Tensor: shape=(35,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13])>,
#  <tf.Tensor: shape=(36,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117])>,
#  <tf.Tensor: shape=(37,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15])>,
#  <tf.Tensor: shape=(38,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182])>,
#  <tf.Tensor: shape=(39,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4])>,
#  <tf.Tensor: shape=(40,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24])>,
#  <tf.Tensor: shape=(41,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265])>,
#  <tf.Tensor: shape=(42,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3])>,
#  <tf.Tensor: shape=(43,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10])>,
#  <tf.Tensor: shape=(44,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22])>,
#  <tf.Tensor: shape=(45,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235])>,
#  <tf.Tensor: shape=(46,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235,  77])>,
#  <tf.Tensor: shape=(47,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235,  77,   8])>,
#  <tf.Tensor: shape=(48,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235,  77,   8,  12])>,
#  <tf.Tensor: shape=(49,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235,  77,   8,  12, 129])>,
#  <tf.Tensor: shape=(50,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235,  77,   8,  12, 129,  90])>,
#  <tf.Tensor: shape=(51,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235,  77,   8,  12, 129,  90,  37])>,
#  <tf.Tensor: shape=(52,), dtype=int64, numpy=
#  array([ 20,   8,   5, 243,  65,  37,  50, 233,  44, 192,  37, 120,  34,
#          25, 232, 120,   3, 261, 207,  72,  15,  65, 193, 123, 209, 248,
#          34,  21,   3,  61, 181,   5,  46,  20,  13, 117,  15, 182,   4,
#          24, 265,   3,  10,  22, 235,  77,   8,  12, 129,  90,  37,  50])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([179, 249])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([179, 249,  16])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([161, 162])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([161, 162,  16])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([16, 87])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([ 16,  87, 213])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([ 16,  87, 213, 191])>,
#  <tf.Tensor: shape=(2,), dtype=int64, numpy=array([234,  17])>,
#  <tf.Tensor: shape=(3,), dtype=int64, numpy=array([234,  17, 208])>,
#  <tf.Tensor: shape=(4,), dtype=int64, numpy=array([234,  17, 208, 214])>,
#  <tf.Tensor: shape=(5,), dtype=int64, numpy=array([234,  17, 208, 214, 156])>]

# %%
max_len=max([len(x) for x in input_seq])

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
padded_input_seq=pad_sequences(input_seq, maxlen=max_len, padding='pre')

# %%
padded_input_seq
# Out:
# array([[  0,   0,   0, ...,   0, 137,   2],
#        [  0,   0,   0, ..., 137,   2,  14],
#        [  0,   0,   0, ...,   0,  12,   8],
#        ...,
#        [  0,   0,   0, ..., 234,  17, 208],
#        [  0,   0,   0, ...,  17, 208, 214],
#        [  0,   0,   0, ..., 208, 214, 156]], shape=(824, 57), dtype=int32)

# %%
x = padded_input_seq[:,:-1]

# %%
x.shape
# Out:
# (824, 56)

# %%
y = padded_input_seq[:,-1]
y
# Out:
# array([  2,  14,   8,   2,  13,  48,  15,  57,  68, 113,  14, 230, 274,
#         13, 122,   7,  45,  33, 109,  31,   3,   9,   5,  28,  45,  70,
#          6,  36, 266,   8,   2,  63,  79,   6,   2,  13,  63,  79,   6,
#          2,  13,   8,  84,  73,  34,   2,  63,  13,  48, 252, 267,  36,
#        270,   8,   2,  92,   6,   2, 113,  14,  10,  22, 241,   2, 222,
#        189, 221, 201,  15,  57,  68, 262,  15,  57,  68,  15, 197,  74,
#        264, 110,  95,  11, 245,   2, 236,  92,  77, 215, 126,  74,  23,
#        107,  22,   7,  71,   6,  20,  14, 107,  23, 126,  74, 250,  61,
#         44,   7,  71,   6,  20, 176, 237,  21,   4, 111,   7, 115,  35,
#         10,   4,  47,   7, 100,   6,   2,  35,  19,  39,  16,  61, 170,
#         34, 123,  21,   3, 111,   7,  35,   3,  11, 220, 256,  23,  51,
#          2, 100,  11,   4, 223,   2, 131, 167,  20,  78, 164,   5,  67,
#         53,  59,  53,  91, 155,   6,   2,  13, 217,   8,   2,  91,  79,
#          6,  19,   2, 115,  16,  19,   2,  16, 203, 139, 218,   8,   2,
#        204, 159,  59,   2, 210, 229,   2,  16,  10,   4,  22, 212, 137,
#          2, 149, 131,  10,  47,   7,  54,  55,  39, 163, 251, 225,  38,
#         35,  43,   3, 253,   7,  38, 148,   4,  29,  20,  13,  21,   4,
#         24,  55,   7, 187, 255, 136,  24,  75,  11,   4,  46,   2,  14,
#         18,   2, 112,   3,  11,  46,   2,  14, 134,   4, 205,  18,   2,
#        112,  10,   4,  22,  40,   5,  67,  19,   2,  42, 202,  43,   3,
#         28,   2,  26,   3,  10,  22,  40,   5,  67,  19,   2,  42, 242,
#         18,  30,  81,  29,   4,   9,   5,  94,   2,  66,  80,   9,   5,
#         94,   2,  66,  25,  10, 175,   3,  87,   2, 160,   3,   9,   5,
#        165, 226,   2,  66, 142,  25,  29,  82,  95,  18,   2,  14,  11,
#         25,  58,   3,  11,  54,  52,  60, 108,  98, 172,  29,  25,   9,
#          5,  28,  39,  70,  30, 141, 246,  72,  32,   9,   5,  28,  19,
#         30,  45,  70,  17,  39,  32,  77,   8,   2, 116,  15,  39,  32,
#        216,  25,  27,   2, 124, 263,   6,  36, 138,  19,  60,  43, 106,
#          2,  14, 122,   7,  45,  33, 109,   8,   2,  62,   6,  45,  33,
#         93,  21,   4,  27,  17,  86,  76, 153,  29,   4,   9,   5,  27,
#        135,  17, 275,  49,  72,  86,  49,  49,   2,  62,  69,   8, 271,
#        127,  55,   2, 128,   3,  28,   2,  26,  34, 227,   3,  11,  46,
#        134,   3,  80,   9,   5, 145,  15,   7,  53,   5, 228,  21,   4,
#         80, 199,   2,  13,  83, 195,   2,  26,  12,   8,   2,  99, 180,
#         47,   7,  84, 127,  99,  69,  55,   2, 128,   3,   9, 196,   2,
#         26,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,  28,   2,
#         26,  17,   2,  32,  12,  96,   4,  29,   9,   5,  58,  52,  59,
#         97,   7,  54,  60, 108, 169, 102, 144,  11,   4, 146,   2,  38,
#         89,  17,   2,  32, 186,   8, 151,  34, 101, 247,   3,  11,  51,
#          2,  89,  64,  30,  33,   8, 147,  93,   3,   9, 173,  33,  17,
#         85,  76,   3,  10,  22,  40,   5,  51,  19,   2,  42,  38,  16,
#         18,   2,  69,   6,  85,  76,   5, 272,  49, 133,  83,  85,  49,
#          3,  10,   9,   5, 174,   2,  33, 135,  43,   2,  13,   8, 184,
#         23,   3,   9,  38,  52,  36, 269,  84, 211,   6,  36, 268,   3,
#         10,  22,  40,   5,  51,   2,  38,  16,  64, 257, 273, 200,  62,
#          8,  44, 104,   6,   2, 198,  13,  48,  11,   4, 171, 185,  18,
#         82,   6,   7,  56,  83,   2,  35,  10,   9,   5, 224,   7,  78,
#        121, 104,  18,  30,  81,  23,  39, 154,  10,  58,   3,  15,   7,
#        140,  17, 140,  56, 130,  35,   4,  46,   2,  14,  75,  11,   4,
#        157, 260,  42,  88, 231, 117, 166,  42,  88,  56,  18,   2,  56,
#        130,  78, 121,  24, 114, 105, 118,  23,   4,  24,  44,  40,   5,
#         28,   2,  26,  17,   2,  32,  12,  96,   4,  29,   9,   5,  58,
#         52,  59,  97,   7,  54,  60, 188,  23,  37,  50,  98, 102,   8,
#          2, 240,   5,  47,   2, 132,  61, 139, 239,   9,   5,  27,   2,
#        124,  48,   6,  36, 138,   9,   5, 258,  19,   2,  13, 259,  24,
#        206,  75, 119,  11,   4,  27,  26,   6,   2, 125,  73,  10,  47,
#          7, 116,   5,  27,  48,   6, 125,  73,  18,  30,  81,  43,   3,
#         27,  15,   2, 238,  53,   9, 101,  65,  37,  50,   8,   7,  71,
#          6,  20,  14,  12, 129,  90,  37,  50,   8,   5, 243,  65,  37,
#         50, 233,  44, 192,  37, 120,  34,  25, 232, 120,   3, 261, 207,
#         72,  15,  65, 193, 123, 209, 248,  34,  21,   3,  61, 181,   5,
#         46,  20,  13, 117,  15, 182,   4,  24, 265,   3,  10,  22, 235,
#         77,   8,  12, 129,  90,  37,  50, 249,  16, 162,  16,  87, 213,
#        191,  17, 208, 214, 156], dtype=int32)

# %%
y.shape
# Out:
# (824,)

# %%
from keras.utils import to_categorical
y = to_categorical(y,num_classes=vocab_size)

# %%
from keras import Sequential
from keras.layers import  Dense , LSTM,Embedding

# %%
model = Sequential([
    Embedding(vocab_size,100,input_length=max_len-1),
    LSTM(150),
    Dense(vocab_size,activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(x, y,epochs=100)
# Out:
# Epoch 1/100
# 2026-03-04 21:13:27.659349: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.0704 - loss: 5.4212
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0813 - loss: 5.0486
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0813 - loss: 4.9679
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0813 - loss: 4.9246
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0813 - loss: 4.8624
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0874 - loss: 4.7617
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0947 - loss: 4.6410
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1371 - loss: 4.4590
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1663 - loss: 4.2444
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1978 - loss: 4.0239
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2306 - loss: 3.7851
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2391 - loss: 3.5833
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2864 - loss: 3.3735
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3240 - loss: 3.1685
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3362 - loss: 2.9909
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3896 - loss: 2.7887
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4296 - loss: 2.6223
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4551 - loss: 2.4577
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5036 - loss: 2.2995
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5231 - loss: 2.1564
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5631 - loss: 2.0121
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5995 - loss: 1.8798
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6371 - loss: 1.7602
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6626 - loss: 1.6391
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7075 - loss: 1.5311
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7233 - loss: 1.4323
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7451 - loss: 1.3395
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7767 - loss: 1.2459
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7840 - loss: 1.1668
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8119 - loss: 1.0864
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8362 - loss: 1.0123
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8374 - loss: 0.9533
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8617 - loss: 0.8908
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8726 - loss: 0.8341
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8871 - loss: 0.7789
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8883 - loss: 0.7326
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9029 - loss: 0.6866
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9066 - loss: 0.6480
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9041 - loss: 0.6120
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9187 - loss: 0.5797
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9199 - loss: 0.5461
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9284 - loss: 0.5142
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9284 - loss: 0.4914
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9272 - loss: 0.4665
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9235 - loss: 0.4460
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9333 - loss: 0.4265
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9381 - loss: 0.4071
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9333 - loss: 0.3876
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9405 - loss: 0.3723
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9369 - loss: 0.3572
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9405 - loss: 0.3437
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9430 - loss: 0.3310
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9442 - loss: 0.3182
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9417 - loss: 0.3088
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9393 - loss: 0.2966
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.2870
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.2779
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9430 - loss: 0.2722
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9442 - loss: 0.2623
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9454 - loss: 0.2560
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.2483
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9430 - loss: 0.2399
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9417 - loss: 0.2355
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9393 - loss: 0.2309
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9466 - loss: 0.2254
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9454 - loss: 0.2194
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.2133
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.2081
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9454 - loss: 0.2059
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9466 - loss: 0.2032
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9454 - loss: 0.1982
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9417 - loss: 0.1936
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.1917
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9393 - loss: 0.1885
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9454 - loss: 0.1838
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9454 - loss: 0.1811
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.1802
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9417 - loss: 0.1773
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9454 - loss: 0.1741
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9417 - loss: 0.1720
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9430 - loss: 0.1691
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9478 - loss: 0.1667
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.1668
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9442 - loss: 0.1639
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9357 - loss: 0.1649
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9454 - loss: 0.1593
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9454 - loss: 0.1582
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9454 - loss: 0.1566
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9430 - loss: 0.1571
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.1542
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9454 - loss: 0.1512
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9417 - loss: 0.1514
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9430 - loss: 0.1491
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9430 - loss: 0.1492
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9417 - loss: 0.1456
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9405 - loss: 0.1478
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9466 - loss: 0.1442
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9442 - loss: 0.1431
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9430 - loss: 0.1443
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9393 - loss: 0.1411

# %%
import time
text = 'what is the course fee'

for i in range(10):
    token_text = vectorization(text)

    padd_token_seq = pad_sequences([token_text], maxlen=max_len,padding='pre')

    preds = np.argmax(model.predict(padd_token_seq))

    for word in vectorization.get_vocabulary():
        if (vectorization.get_vocabulary().index(word) == preds)and (text.split(word)[1]!=" "+word) :
            text = text + ' '+ word

            print(text)
            time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 14
#      12 if vectorization.get_vocabulary().index(word) == preds:
#      13     text = text + ' '+ word
# ---> 14     if text.split(word+" ")[1]==word:
#      15         text.replace(word,"")
#      16         print(text)
#
# IndexError: list index out of range

# %%
token = vectorization('what is the fee')
padd_tokenized = pad_sequences([token], maxlen=max_len,padding='pre')

# %%
preds = model.predict(padd_tokenized)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
import numpy as np

# %%
print(np.argmax(preds))
# Out:
# 15
